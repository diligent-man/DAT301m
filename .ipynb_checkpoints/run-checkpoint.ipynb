# %% [markdown]
# # Training info
# 1/ Model: MobilenetV2<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: No<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x7f9b708b8af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_file5hvufvvo.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# | tation)                                                                  |
# ...

# %% [markdown]
# # Training info
# 1/ Model: MobilenetV2<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: Yes<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x7e27c3a8baf0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_fileqtnpvitv.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# ...

# %% [markdown]
# # Training info
# 1/ Model: Resnet50<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: No<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x7f7f8c820af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_file6jbrqo59.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# | tation)                                                                  |
# ...

# %% [markdown]
# # Training info
# 1/ Model: Resnet50<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: Yes<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x75f27caf0af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_file2v1u3j0j.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# ...

# %% [markdown]
# # Training info
# 1/ Model: VGG16<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: No<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x71986b47daf0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_file6cizw922.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# | tation)                                                                  |
# ...

# %% [markdown]
# # Training info
# 1/ Model: VGG16<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: Yes<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x7799dd6ceaf0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_filex5ulswxq.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# ...

# %% [markdown]
# # Training info
# 1/ Model: EfficientNetB0<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: No<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x7ceedf8d2af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_filew5ooddya.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# | tation)                                                                  |
# ...

# %% [markdown]
# # Training info
# 1/ Model: EfficientNetB0<br>
# 2/ LR: 1e-4<br>
# 3/ Pretrained: Yes<br>

# %%
# !python train_main1.py
# Out:
# Using TensorFlow backend
# WARNING:tensorflow:AutoGraph could not transform <function _read_img at 0x74f3c788aaf0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: annotated name 'img' can't be nonlocal (__autograph_generated_filesitu6uiz.py, line 23)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ...
#  preprocessing_and_augmenta  (None, 224, 224, 3)       0         Y
#  tion (Sequential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_rotation (RandomRo  (None, 800, 800, 3)       0         Y         |
# ...
